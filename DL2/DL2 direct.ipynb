# %%
import numpy as np
from numpy.ma.core import argmax
import pandas as pd
from matplotlib import cm
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#import os
import time
from sklearn.metrics import confusion_matrix, accuracy_score, auc
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.callbacks import EarlyStopping
from keras import models
from keras import layers
from keras.datasets import imdb

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
print("Training data: ")
print(X.shape)
print(y.shape)
print("Classes: ")
print(np.unique(y))
print("Number of words: ")
print(len(np.unique(np.hstack(X))))
print("Review length: ")
result = [len(x) for x in X]
print("Mean %.2f words (%f)" % (np.mean(result), np.std(result))) # Ploting the review length
plt.boxplot(result)
plt.show()
# Out:
# Training data:
# (50000,)
# (50000,)
# Classes:
# [0 1]
# Number of words:
# 88585
# Review length:
# Mean 234.76 words (172.911495)

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=5000):
    # Function for vectorizing data
    results = np.zeros((len(sequences), dimension))
    # Creating an all-zero matrix of shape (len(sequences), dimension)
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
        # Set specific indices of results[i] to 1s
    return results

# %%
# Creating Training and Testing Sets and Preprocessing them
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=5000)
# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)
# Our vectorized labels one-hot encoder
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
# Creating the DNN Model
model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(5000,)))
model.add(layers.Dense(32, activation='relu',))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
#Set validation set aside
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
# Compiling Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
start_time_m1 = time.time()
history = model.fit(partial_x_train,
partial_y_train,
epochs=20,
batch_size=512,
validation_data=(x_val, y_val))
total_time_m1 = time.time() - start_time_m1
print("The Dense Convolutional Neural Network 1 layer took %.4f seconds to train." % (total_time_m1))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 5s 95ms/step - loss: 0.5206 - acc: 0.7723 - val_loss: 0.3534 - val_acc: 0.8631
# Epoch 2/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2722 - acc: 0.8982 - val_loss: 0.2888 - val_acc: 0.8853
# Epoch 3/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.2005 - acc: 0.9245 - val_loss: 0.2909 - val_acc: 0.8824
# Epoch 4/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.1625 - acc: 0.9405 - val_loss: 0.3088 - val_acc: 0.8776
# Epoch 5/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.1343 - acc: 0.9537 - val_loss: 0.3344 - val_acc: 0.8750
# Epoch 6/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1142 - acc: 0.9620 - val_loss: 0.3804 - val_acc: 0.8709
# Epoch 7/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0957 - acc: 0.9685 - val_loss: 0.3966 - val_acc: 0.8682
# Epoch 8/20
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0753 - acc: 0.9775 - val_loss: 0.4333 - val_acc: 0.8636
# Epoch 9/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0597 - acc: 0.9842 - val_loss: 0.4714 - val_acc: 0.8630
# Epoch 10/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0455 - acc: 0.9906 - val_loss: 0.5179 - val_acc: 0.8578
# Epoch 11/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0352 - acc: 0.9949 - val_loss: 0.5522 - val_acc: 0.8588
# Epoch 12/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0255 - acc: 0.9969 - val_loss: 0.5960 - val_acc: 0.8573
# Epoch 13/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0183 - acc: 0.9990 - val_loss: 0.6347 - val_acc: 0.8566
# Epoch 14/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0136 - acc: 0.9995 - val_loss: 0.6698 - val_acc: 0.8573
# Epoch 15/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0103 - acc: 0.9997 - val_loss: 0.7020 - val_acc: 0.8558
# Epoch 16/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0077 - acc: 0.9999 - val_loss: 0.7372 - val_acc: 0.8554
# Epoch 17/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0059 - acc: 0.9999 - val_loss: 0.7684 - val_acc: 0.8555
# Epoch 18/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.7986 - val_acc: 0.8543
# Epoch 19/20
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.8296 - val_acc: 0.8548
# Epoch 20/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.8589 - val_acc: 0.8542
# The Dense Convolutional Neural Network 1 layer took 20.8010 seconds to train.

# %%
# Assuming you have a `history` object obtained from model training
history_dict = history.history
print(history_dict.keys())  # To see what keys are available in the history dictionary
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# Extracting the training and validation accuracy and loss
acc = history_dict['acc']
val_acc = history_dict['val_acc']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

# %%
# Generating the epochs
epochs = range(1, len(acc) + 1)

# %%
# Plotting model loss
plt.plot(epochs, loss, 'bo', label='Training loss') # "bo" is for "blue dot"
plt.plot(epochs, val_loss, 'b', label='Validation loss') # b is for "solid blue line"
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()

# %%
# clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

# %%
# Plotting model accuracy
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Model Summary
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                160032
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 161121 (629.38 KB)
# Trainable params: 161121 (629.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Predictions
pred = model.predict(x_test)
classes_x=np.argmax(pred,axis=1)
accuracy_score(y_test,classes_x)
# Out:
# 782/782 [==============================] - 3s 4ms/step
# 0.5

# %%
#Confusion Matrix
conf_mat = confusion_matrix(y_test, classes_x)
print(conf_mat)
# Out:
# [[12500     0]
#  [12500     0]]

# %%
conf_mat_normalized = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
sns.heatmap(conf_mat_normalized)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
#Dense with Two Layer
model2 = models.Sequential()
model2.add(layers.Dense(32, activation='relu', input_shape=(5000,)))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(32, activation='relu'))
model2.add(layers.Dense(1, activation='sigmoid'))

# %%
# Compiling Model
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
start_time_m2 = time.time()
history= model2.fit(partial_x_train,
partial_y_train,
epochs=20,
batch_size=512,
validation_data=(x_val, y_val))
total_time_m2 = time.time() - start_time_m2
print("The Dense Convolutional Neural Network 2 layers took %.4f seconds to train." % (total_time_m2))

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 59ms/step - loss: 0.5145 - acc: 0.7803 - val_loss: 0.3344 - val_acc: 0.8648
# Epoch 2/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.2582 - acc: 0.8997 - val_loss: 0.2919 - val_acc: 0.8820
# Epoch 3/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.1869 - acc: 0.9305 - val_loss: 0.3078 - val_acc: 0.8806
# Epoch 4/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1472 - acc: 0.9461 - val_loss: 0.3413 - val_acc: 0.8732
# Epoch 5/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1211 - acc: 0.9580 - val_loss: 0.3771 - val_acc: 0.8667
# Epoch 6/20
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0974 - acc: 0.9679 - val_loss: 0.4253 - val_acc: 0.8640
# Epoch 7/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0758 - acc: 0.9754 - val_loss: 0.4974 - val_acc: 0.8628
# Epoch 8/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0640 - acc: 0.9798 - val_loss: 0.5478 - val_acc: 0.8586
# Epoch 9/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0501 - acc: 0.9858 - val_loss: 0.6003 - val_acc: 0.8548
# Epoch 10/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0382 - acc: 0.9909 - val_loss: 0.6505 - val_acc: 0.8543
# Epoch 11/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0272 - acc: 0.9945 - val_loss: 0.7208 - val_acc: 0.8561
# Epoch 12/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0199 - acc: 0.9965 - val_loss: 0.7682 - val_acc: 0.8502
# Epoch 13/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0149 - acc: 0.9979 - val_loss: 0.8188 - val_acc: 0.8535
# Epoch 14/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0093 - acc: 0.9990 - val_loss: 0.8626 - val_acc: 0.8539
# Epoch 15/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0060 - acc: 0.9995 - val_loss: 0.9008 - val_acc: 0.8529
# Epoch 16/20
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0041 - acc: 0.9996 - val_loss: 0.9377 - val_acc: 0.8531
# Epoch 17/20
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0030 - acc: 0.9998 - val_loss: 0.9692 - val_acc: 0.8527
# Epoch 18/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0022 - acc: 0.9999 - val_loss: 1.0100 - val_acc: 0.8530
# Epoch 19/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.0566 - val_acc: 0.8537
# Epoch 20/20
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.0966 - val_acc: 0.8536
# The Dense Convolutional Neural Network 2 layers took 19.6362 seconds to train.

# %%
# Plotting Loss
plt.plot(epochs, loss, 'bo', label='Training loss') # "bo" is for "blue dot"
plt.plot(epochs, val_loss, 'b', label='Validation loss') # b is for "solid blue line"
plt.title('DNN 2 layer Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()

# %%
# clear figure
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

# %%
# Plotting Accuracy
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('DNN 2 layer Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

print(model2.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 32)                160032
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 162177 (633.50 KB)
# Trainable params: 162177 (633.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Predictions
pred = model2.predict(x_test)
classes_x=np.argmax(pred,axis=-1)
accuracy_score(y_test,classes_x)
# Out:
# 782/782 [==============================] - 1s 2ms/step
# 0.5
